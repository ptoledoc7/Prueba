# %% [markdown]
# <a href="https://colab.research.google.com/github/ptoledoc7/Prueba/blob/main/Copia_de_01_script_ETL_personalidad.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Tema 1: Carga de datos

# %% [markdown]
# ## **Importando base de datos**

# %%
# Google Auth
from google.colab import auth
auth.authenticate_user()

# %%
# API Client
from google.auth import default
creds, _ = default()

# %%
# gspread Authorization
import gspread
gc = gspread.authorize(creds)

# %%
# Accediendo al Google Sheet
url_reportes = "https://docs.google.com/spreadsheets/d/1lCdWiaaC2sna7rN4YfPuUD9xGNve32IeQAzIP4PmbkE/edit?usp=sharing"
gsheets = gc.open_by_url(url_reportes)
sheets = gsheets.worksheet("reportes_1").get_all_values()

# %%
type(sheets)
print(sheets)
# Out:
# [['Contrato', 'NAP', 'Puerto', 'Central', 'Nodo', 'Posicion', 'Modelo', 'PwRx', 'PwRx CATV'], ['AD084149', 'HP101/2S16/2', '5', 'Hamacas', 'HUAWEI', '0-3-4-16', 'HG8247H', '-28.54', '-'], ['AD243402', 'NC-AY1-0016-01B-T', '4', 'Hamacas3', 'HUAWEI', '0-2-11-49', 'HG8247H', '-32.21', '-13.22'], ['AD245714', 'NC-AY1-0016-01B-T', '3', 'Hamacas3', 'HUAWEI', '0-2-11-4', 'HG8245H2', '-29.58', '-'], ['AD244993', 'NC-AY1-0016-01B-T', '1', 'Hamacas3', 'HUAWEI', '0-2-11-19', 'HG8245H2', '-30.96', '-'], ['AD014791', 'NC-AY1-U007-01E-T', '3', 'Hamacas', 'HUAWEI', '0-4-6-59', 'HG8247H', '-30.96', '-14.19'], ['AD120886', 'NC-AY1-U007-01E-T', '4', 'Hamacas', 'HUAWEI', '0-4-6-37', 'HG8245H2', '-28.86', '-'], ['AD097231', 'NC-AY1-U012-01B-T', '5', 'Hamacas', 'HUAWEI', '0-4-6-21', 'HG8045H', '-28.54', '-'], ['AD097232', 'NC-AY1-U012-01B-T', '4', 'Hamacas', 'HUAWEI', '0-4-6-23', 'HG8045H', '-28.54', '-'], ['AD081102', 'NC-AY1-U012-01B-T', '3', 'Hamacas', 'HUAWEI', '0-4-6-2', 'HG8247H', '-29.58', '-12.43'], ['AD084760', 'NC-AY1-U012-01B-T', '2', 'Hamacas', 'HUAWEI', '0-4-6-61', 'HG8245H2', '-31.54', '-'], ['AD048212', 'NC-AY1-U012-01B-T', '1', 'Hamacas', 'HUAWEI', '0-4-6-1', 'HG8247H', '-29.21', '-11.76'], ['AD233638', 'NC-AY1-U012-02D-T', '3', 'Hamacas3', 'HUAWEI', '0-2-2-30', 'HG8247H', '-30.96', '-'], ['AD240921', 'NC-AY1-U015-01B-T', '1', 'Hamacas', 'HUAWEI', '0-4-6-7', 'HG8247H', '-30.45', '-13.22'], ['AD184902', 'NC-AY1-U022-01B-T', '5', 'Hamacas', 'HUAWEI', '0-4-6-16', 'HG8247H', '-28.86', '-11.01'], ['AD184906', 'NC-AY1-U022-01B-T', '4', 'Hamacas', 'HUAWEI', '0-4-6-15', 'HG8247H', '-30', '-12.35'], ['AD184904', 'NC-AY1-U022-01B-T', '3', 'Hamacas', 'HUAWEI', '0-4-6-12', 'HG8247H', '-30', '-11.97'], ['AD184910', 'NC-AY1-U022-01B-T', '2', 'Hamacas', 'HUAWEI', '0-4-6-13', 'HG8247H', '-28.86', '-11.63'], ['AD187064', 'NC-AY1-U024-02B-T', '4', 'Hamacas3', 'HUAWEI', '0-2-2-3', 'HG8247H', '-28.24', '-'], ['AD140700', 'NC-AY1-U027-01B-T', '5', 'Hamacas3', 'HUAWEI', '0-1-10-26', 'HG8247H', '-29.58', '-12.81'], ['AD008733', 'NC-AY1-U027-01B-T', '3', 'Hamacas3', 'HUAWEI', '0-1-10-15', 'HG8247H', '-30.45', '-13.68'], ['AD238304', 'NC-AY1-U074-01B-T', '5', 'Hamacas3', 'HUAWEI', '0-2-11-9', 'HG8247H', '-28.54', '-11.46'], ['AD240320', 'NC-AY1-U074-01C-T', '7', 'Hamacas3', 'HUAWEI', '0-2-11-29', 'HG8245H2', '-28.86', '-'], ['AD242570', 'NC-AY1-U074-01C-T', '5', 'Hamacas3', 'HUAWEI', '0-2-11-44', 'HG8245H2', '-28.86', '-'], ['AD235716', 'NC-G02-0121-01E', '8', 'Grigota', 'HUAWEI', '0-4-2-84', 'HG8245H2', '-30', '-'], ['AD072027', 'NC-G03-00VO-02B', '1', 'Grigota', 'HUAWEI', '0-0-1-28', 'HG8240H', '-30', '-'], ['AD191565', 'NC-H01-0069-01C-T', '9', 'Hamacas', 'HUAWEI', '0-3-1-73', 'HG8247H', '-28.24', '-'], ['AD191185', 'NC-H01-0193-04C', '6', 'Hamacas', 'HUAWEI', '0-3-0-3', 'HG8247H', '-31.54', '-'], ['AD172208', 'NC-H01-0346-01D-T', '2', 'Hamacas3', 'HUAWEI', '0-2-13-9', 'HG8110H', '-28.86', '-'], ['AD244034', 'NC-H01-0346-01D-T', '4', 'Hamacas3', 'HUAWEI', '0-2-13-0', 'HG8045H', '-28.86', '-'], ['AD209289', 'NC-H01-0346-02B', '4', 'Hamacas3', 'HUAWEI', '0-1-3-1', 'HG8045H', '-29.58', '-'], ['AD238509', 'NC-LGG-0009-02B-T', '10', 'Grigota2', 'HUAWEI', '0-1-1-55', 'HG8012H', '-30.45', '-7.1'], ['AD237504', 'NC-LGG-0009-02C-T', '2', 'Grigota2', 'HUAWEI', '0-1-1-10', 'HG8245H2', '-28.86', '-'], ['AD243705', 'NC-LGG-0009-02E-T', '3', 'Grigota2', 'HUAWEI', '0-1-1-0', 'HG8247H', '-29.21', '-4.32'], ['AD215438', 'NC-LGG-0009-02E-T', '2', 'Grigota2', 'HUAWEI', '0-1-1-7', 'HG8045H', '-30.96', '-'], ['AD244362', 'NC-LGG-0009-02E-T', '1', 'Grigota2', 'HUAWEI', '0-1-1-3', 'HG8245H2', '-30.96', '-'], ['AD195306', 'NC-LGG-0152-01B', '1', 'Grigota', 'HUAWEI', '0-3-2-80', 'HG8247H', '-30.45', '-9.98'], ['AD185780', 'NC-LGG-0152-01B', '2', 'Grigota', 'HUAWEI', '0-3-2-21', 'HG8247H', '-30.96', '-10.46'], ['AD110348', 'NC-LGG-0152-01B', '6', 'Grigota', 'HUAWEI', '0-3-2-23', 'HG8045H', '-29.58', '-'], ['AD224479', 'NC-LGG-0210-03B', '6', 'Grigota', 'HUAWEI', '0-3-5-74', 'HG8 ...

# %%
# Convirtiendo en un df
import pandas as pd
df = pd.DataFrame(sheets[1:], columns = sheets[0])

# %% [markdown]
# ## Inspección data frame

# %%
type(df)

# %%
# Visualizando las primeras filas
df.head()

# %%
# Mirada general
df.info()

# %%
# Tipo de datos
df["Sexo"].dtype

# %%
# Número de filas y columnas
df.shape

# %%
# Número de filas
len(df)

# %%
df.columns

# %%
len(df.columns)

# %% [markdown]
# # **Tema 2: Transformación de datos**

# %% [markdown]
# ## **Valores perdidos**

# %% [markdown]
# ### **Identificación de los NAs**

# %%
# Los NAs en realidad son strings vacíos
import numpy as np
df.replace("", np.nan, inplace = True)

# %%
df['Escribe tu edad exacta'].isna().value_counts()

# %% [markdown]
# ### **Omitiendo**

# %%
df['Escribe tu edad exacta'].dtype

# %%
df['Escribe tu edad exacta'] = pd.to_numeric(df['Escribe tu edad exacta'], errors = 'coerce')

# %%
df['Escribe tu edad exacta'].dtype

# %%
df['Escribe tu edad exacta'].mean()

# %%
edad_promedio = df['Escribe tu edad exacta'].mean()

# %% [markdown]
# ### **Reemplazo por la media**

# %%
# creando df2
df2 = df.copy()

# %%
# reemplazo por la media
df2["edad2"] = df2["Escribe tu edad exacta"].fillna(edad_promedio)

# %% [markdown]
# **Reubicando la columna edad2**

# %%
# Colocar los nombres de las columnas en una lista
lista_columnas = df2.columns.to_list()

# %%
# Quitar temporalmente edad2 de la lista
lista_columnas.remove("edad2")

# %%
# obteniendo el índice de la columna 'after'
lista_columnas.index("Escribe tu edad exacta")

# %%
# insertando 'edad2' después de 'Escribe tu edad exacta'
lista_columnas.insert(lista_columnas.index("Escribe tu edad exacta") + 1, "edad2")

# %%
# Reordenando y guadando en df2
df2 = df2[lista_columnas]

# %% [markdown]
# **Emulando relocate() de R en Python**

# %%
def relocate(df, columna, after):
  lista_columnas = df.columns.to_list()
  lista_columnas.remove(columna)
  lista_columnas.insert(lista_columnas.index(after) + 1, columna)
  return df[lista_columnas]

# %%
relocate(
    df = df2,
    columna = "edad2",
    after = "Escribe tu edad exacta"
)

# %% [markdown]
# ### **Eliminar la fila completa**

# %%
df2 = df2.dropna()

# %%
df2.shape

# %% [markdown]
# ## **Estandarización de variables**

# %% [markdown]
# ### **Normalización**

# %%
from sklearn.preprocessing import StandardScaler

# %%
# instanciando StandardScaler()
normalizador = StandardScaler()

# %%
# normalizando
normalizador.fit_transform(df2[["edad2"]])

# %%
# Creando df3
df3 = df2.copy()

# %%
df3["edadZ"] = normalizador.fit_transform(df2[["edad2"]])

# %%
# Reubicando edadZ
df3 = relocate(
    df = df3,
    columna = "edadZ",
    after = "edad2"
)

# %% [markdown]
# ### **Rango**

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
# instanciando MinMaxScaler()
rango = MinMaxScaler()

# %%
rango.fit_transform(df3[["edad2"]])

# %%
df3["edadRango"] = rango.fit_transform(df3[["edad2"]])

# %%
df3 = relocate(
    df = df3,
    columna = "edadRango",
    after = "edadZ"
)

# %%
df3.head()

# %% [markdown]
# ## **Agrupaciones**

# %% [markdown]
# ### **Numéricas**

# %%
cortes = [-float("inf"), 18, 21, float("inf")]
etiquetas = ["18 o menos", "19 a 21", "Más de 21"]

# %%
# Creando columna edadGR
df3["edadGR"] = pd.cut(
    df3["edad2"],
    bins = cortes,
    labels = etiquetas
)

# %%
# comparando
pd.DataFrame({
    "original": df3["edad2"],
    "edadGR": df3["edadGR"]
})

# %% [markdown]
# ### **Categóricas**

# %%
# índices del df3
df3.info()

# %%
# identificando los niveles
pd.unique(df3.iloc[:,7])

# %%
df3.iloc[:,7].value_counts()

# %%
# prueba lógica top 2 box
df3.iloc[:,7].isin(["Totalmente verdadero", "Un poco verdadero"]).value_counts()

# %% [markdown]
# **Dummitización**

# %%
# función condicional normal
def top2box(x):
  if x in ["Totalmente verdadero", "Un poco verdadero"]:
    return 1
  else:
    return 0

# %%
# aplicando la función
df3.iloc[:,7].apply(top2box)

# %%
# frecuencias
df3.iloc[:,7].apply(top2box).value_counts()

# %% [markdown]
# **Funciones lambda**

# %%
df3.iloc[:,7].apply(lambda x: 1 if x in ["Totalmente verdadero", "Un poco verdadero"] else 0).value_counts()

# %% [markdown]
# **Escala ordinal**

# %%
import numpy as np

# %%
# niveles
pd.unique(df3.iloc[:,7])

# %%
condiciones = [
    df3.iloc[:,7] == "Totalmente falso",
    df3.iloc[:,7] == "Un poco falso",
    df3.iloc[:,7] == "No lo sé",
    df3.iloc[:,7] == "Un poco verdadero",
    df3.iloc[:,7] == "Totalmente verdadero"
]

opciones = [1, 2, 3, 4, 5]

# %%
ordinal = np.select(
    condlist = condiciones,
    choicelist = opciones,
    default = np.nan
)

# %%
# como se trata de un objeto de numpy, el método es distinto
np.unique(ordinal, return_counts = True)

# %%
# si quisieras usar value_counts()...
pd.Series(ordinal).value_counts()

# %% [markdown]
# **Bucles**

# %% [markdown]
# Manera convencional

# %%
# creando df4
df4 = df3.copy()

# %%
df4.columns

# %%
# crear una lista vacía
frases = []

# creando bucle para llenar vector vacío
for col in df4.columns:
  if col.startswith("Según tu"):
    frases.append(col)

# %%
frases

# %%
# creando otro bucle, esta vez para dummitizar
for var in frases:
  df4[var] = df4[var].apply(top2box)

# %% [markdown]
# Manera pythonica

# %%
# creando df5
df5 = df3.copy()

# %%
# crear una lista vacía
frases = []

# usando list comprehension
frases = [col for col in df5.columns if col.startswith("Según tu")]

# %%
# creando el bucle para dummitizar con función lambda
for var in frases:
  df5[var] = df5[var].apply(lambda x: 1 if x in ["Totalmente verdadero", "Un poco verdadero"] else 0)

# %% [markdown]
# # **Tema 3: Manipulación de data frames**

# %% [markdown]
# ## **Selección de columnas**

# %%
df5["Sexo"]

# %%
df5[["Sexo"]]

# %%
df5[["Sexo", "edad2"]]

# %%
df5.drop(columns = ["Marca temporal"], axis = 1)

# %%
df5[[col for col in df5.columns if col.startswith("edad")]]

# %%
df5[[col for col in df5.columns if col.endswith("00")]]

# %%
df5.drop(df5.iloc[:,0:5], axis = 1)

# %%
df5.filter(like = "edad", axis = 1)

# %% [markdown]
# ## **Selección de filas**

# %%
df5[df5["Sexo"] == "Mujer"]

# %%
df5[df5["Sexo"] != "Hombre"]

# %%
df5[df5["edad2"] >= 20]

# %%
df5[
    (df5["edad2"] >= 18) &
    (df5["edad2"] <= 21) &
    (df5["Sexo"] == "Hombre")
][["Sexo", "edad2"]]

# %%
df3[df3.iloc[:,7].str.contains("falso", regex = False)]

# %% [markdown]
# ## **Cambio de nombre de columnas**

# %%
df6 = df5.copy()

# %% [markdown]
# ### **Apps**

# %%
df6.info()

# %% [markdown]
# **Paso 1:** Crear una lista con los nuevos nombres

# %%
apps = ["TikTok", "Instagram", "Facebook", "YouTube"]

# %%
apps

# %% [markdown]
# **Paso 2:** Crear un dict que contenga los nombres antiguos como claves (key) y los nuevos como valor (value)

# %%
# zip() crea tuplas (nombre antiguo, nombre nuevo)
# dict() almacena en un diccionario
apps_dict = dict(
    zip(
        [col for col in df6.columns if col.endswith("00")],
        apps
    )
)

# %%
apps_dict

# %% [markdown]
# **Paso 3:** Reemplazar

# %%
df6.rename(apps_dict, axis = 1, inplace = True)

# %%
df6.info()

# %% [markdown]
# ### **Frases**

# %% [markdown]
# **Paso 0:** Convertir la lista a pd.Series

# %%
type(frases)

# %%
frases2 = pd.Series(frases)

# %%
type(frases2)

# %% [markdown]
# **Paso 1:** Crear una lista con los nuevos nombres

# %%
# Solución de Samuel Vizcarra
# con corchetes: \[.*?\]
# sin corchetes: \[(.*?)\]
frases2 = frases2.str.extract("\\[(.+)\\]")[0]

# %% [markdown]
# **Paso 2:** Crear un dict que contenga los nombres antiguos como claves (key) y los nuevos como valor (value)

# %%
frases_dict = dict(zip(frases, frases2))

# %%
frases_dict

# %% [markdown]
# **Paso 3:** Reemplazar

# %%
df6.rename(frases_dict, axis = 1, inplace = True)

# %%
df6.info()

# %% [markdown]
# ## **Pivotado de base de datos**

# %% [markdown]
# ### **Pivot Longer**

# %%
df7 = df6.melt(
    # identifiers
    id_vars = ["Marca temporal", "Sexo", "edad2"],
    value_vars = apps,
    var_name = "app",
    value_name = "time"
)

# %%
df7.shape

# %%
df7

# %% [markdown]
# ### **Pivot Wider**

# %%
df8 = df7.pivot(
    # identifiers
    index = ["Marca temporal", "Sexo", "edad2"],
    columns = "app",
    values = "time"
)

# %%
# Notar que las columnas se ven raras
df8.head()

# %%
# Los identifiers NO son columnas
df8.info()

# %%
# Reiniciando index
df8.reset_index(inplace = True)

# %%
df8.head()

# %%
# Quitando nombre al grupo de columnas
df8.columns.name = None

# %%
df8.head()

# %% [markdown]
# # **Tema 4: Detección de outliers**

# %% [markdown]
# **Transformación de horas a númerico**

# %%
# split separa textos
"02:30:45".split(":")

# %%
# función conversora
def tiempo_a_num(x):
  return int(x.split(":")[0]) + int(x.split(":")[1])/60 + int(x.split(":")[2])/60**2

# %%
# probando la función
tiempo_a_num("00:30:00")

# %%
df7["time"] = df7["time"].apply(tiempo_a_num)

# %% [markdown]
# ## **Gráfica: Boxplot**

# %%
import plotly.express as px

# %%
px.box(df7, y = "time")

# %% [markdown]
# **Apertura por app**

# %% [markdown]
# **Usando plotly**

# %%
px.box(
    # esta parte es la equivalente a ggplot()
    df7,
    x = "app",
    y = "time",
    color = "app",
    # points = "all"
).update_layout(
    # update_layout es el equivalente a theme() en ggplot
    title = "Apertura por app",
    showlegend = False,
    xaxis_title = "App",
    yaxis_title = "Tiempo (horas)",
    plot_bgcolor = "white"
).update_traces({
    "marker": {"size": 8},
    "line": {"width": 4},
    "fillcolor": "white"
})

# %% [markdown]
# **Usando ggplot**

# %%
from plotnine import *

# %%
# Los paréntesis especifican que todo forma parte de un solo statement
(
    ggplot(df7, aes(x = "app", y = "time", color = "app"))
    + geom_boxplot()
    + geom_jitter(width = 0.2, alpha = 0.5)
    + theme_minimal()
    + theme(legend_position = "none")
    + labs(
        title = "Apertura por app",
        x = "App",
        y = "Tiempo (horas)"
    )
).draw()

# %% [markdown]
# ## **Tratamiento**

# %%
df9 = df7.copy()

# %%
condiciones = (
    ((df9["app"] == "TikTok")    & (df9["time"] > 16.37)) |
    ((df9["app"] == "Instagram") & (df9["time"] > 12))    |
    ((df9["app"] == "Facebook")  & (df9["time"] > 10))    |
    ((df9["app"] == "YouTube")   & (df9["time"] > 9))
)

# %%
df9["outlier"] = np.where(condiciones, "outlier", "No outlier")

# %%
df9["promedio"] = df9.groupby("app")["time"].transform("mean")

# %%
df9["time2"] = np.where(df9["outlier"] == "outlier", df9["promedio"], df9["time"])

# %%
df9

# %% [markdown]
# # **Tema 5: Exploratory Data Analysis (EDA)**

# %% [markdown]
# ## **Variables categóricas**

# %%
# conteo
df6["edadGR"].value_counts()

# %%
# proporciones
df6["edadGR"].value_counts(normalize = True)

# %%
# orden ascendente
df6["edadGR"].value_counts().sort_values()

# %%
# orden descendente
df6["edadGR"].value_counts().sort_values(ascending = False)

# %%
# de Series a DataFrame
df_edadGR = df6["edadGR"].value_counts().reset_index()
df_edadGR.columns = ["edadGR", "n"]

# %%
# orden ascendente por columna
df_edadGR.sort_values(by = "n", ascending = True)

# %%
# crear nuevas columnas calculadas
df_edadGR["prop"] = df_edadGR["n"] / df_edadGR["n"].sum()

# %%
df_edadGR

# %% [markdown]
# ## **Variables numéricas**

# %%
df9["time"].describe()
